# %%
import pandas as pd

# %%
reportdata = pd.read_csv("https://raw.githubusercontent.com/tderoon/Cybereconomicsgroup4/master/17-09-2020-urlhaus.abuse.ch.csv")

# %%
reportdata
# Out:
#             id        dateadded  \
# 0       544165  9/17/2020 10:10
# 1       544163  9/17/2020 10:10
# 2       544164  9/17/2020 10:10
# 3       544162  9/17/2020 10:10
# 4       544161  9/17/2020 10:10
# ...        ...              ...
# 108757  435287   8/18/2020 0:04
# 108758  435286   8/18/2020 0:04
# 108759  435285   8/18/2020 0:04
# 108760  435284   8/18/2020 0:03
# 108761  435283   8/18/2020 0:03
#
#                                                       url url_status  \
# 0                        http://115.98.1.103:56034/Mozi.a    offline
# 1                       http://115.97.82.185:47119/Mozi.m     online
# 2                       http://115.97.83.180:58110/Mozi.m     online
# 3                       http://115.98.145.51:60363/Mozi.m     online
# 4                       http://115.97.80.186:42284/Mozi.m     online
# ...                                                   ...        ...
# 108757                  http://14.157.58.114:35300/Mozi.m    offline
# ...

# %%
tags_dict=(reportdata['tags']. value_counts()).to_dict()

# %%
tags_dict
# Out:
# {'elf,Mozi': 50009,
#  '32-bit,elf,mips': 34233,
#  'Mozi': 3699,
#  'doc,emotet,epoch2,heodo': 2292,
#  'elf': 1563,
#  'exe,opendir': 1547,
#  'doc,emotet,epoch1,heodo': 1416,
#  '32-bit,arm,elf': 1216,
#  'exe,ono70,Trickbot': 1087,
#  'elf,mirai': 1010,
#  'exe,ono70,opendir,Trickbot': 1002,
#  'bashlite,elf,gafgyt': 909,
#  'zip': 876,
#  'doc,ono66,Trickbot': 806,
#  'doc,emotet,epoch3,heodo': 748,
#  'None': 666,
#  'exe,ono66,Trickbot': 609,
#  'emotet,epoch1,exe,heodo': 519,
#  'emotet,epoch2,exe,heodo': 444,
#  'emotet,epoch3,exe,heodo': 428,
#  'dll,IcedID,shathak,TA551': 272,
#  'bazaloader,exe,opendir': 248,
#  'exe': 218,
#  'opendir,zip': 194,
#  'shellscript': 175,
#  'encrypted,GuLoader': 159,
#  'ddos,elf,mirai': 150,
#  'DDoS Bot,elf,mirai': 128,
#  'AgentTesla,exe': 108,
#  'dll,geofenced,IcedID': 104,
#  'exe,ono72,opendir,Trickbot': 101,
#  'Dridex': 100,
#  'dll,geofenced,IcedID,USA': 96,
#  'doc,emotet,epoch2': 93,
#  'doc,emotet,epoch1': 57,
# ...

# %%
len(tags_dict)
# Out:
# 307
